# %%
import geopandas
import psycopg2
import folium
import matplotlib
import pysal
bairros_com_escolas = geopandas.read_file("data/bairros_com_escolas.geojson")
bairros_com_escolas.plot(column='numpoints', cmap='YlOrRd', scheme='fisher_jenks', figsize=(16, 14), facecolor='w', edgecolor='k')
